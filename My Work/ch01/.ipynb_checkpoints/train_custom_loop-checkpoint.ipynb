# %%
import sys
sys.path.append('..')
import import_ipynb
import numpy as np
from common.optimizer import SGD
from dataset import spiral
import matplotlib.pyplot as plt
from two_layer_net import TwoLayerNet
# Out:
# importing Jupyter notebook from ../common/optimizer.ipynb
# importing Jupyter notebook from ../dataset/spiral.ipynb
# importing Jupyter notebook from two_layer_net.ipynb
# importing Jupyter notebook from ../common/layers.ipynb
# importing Jupyter notebook from ../common/functions.ipynb

# %%
# 하이퍼 파라미터 설정

max_epoch = 300
batch_size = 30
hidden_size = 10
learning_rate = 1.0

# %%
# 데이터 읽기, 모델 준비

x, t = spiral.load_data()
model = TwoLayerNet(input_size = 2, hidden_size = hidden_size, output_size = 3)
optimizer = SGD(lr = learning_rate)

# 학습에 사용하는 변수
data_size = len(x)
max_iters = data_size // batch_size
total_loss = 0
loss_count = 0
loss_list = []

# %%
for epoch in range(max_epoch):
    # 데이터 뒤섞기
    idx = np.random.permutation(data_size)
    x = x[idx]
    t = t[idx]
    
    for iters in range(max_iters):
        batch_x = x[iters*batch_size:(iters+1)*batch_size]
        batch_t = t[iters*batch_size:(iters+1)*batch_size]

        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        
        total_loss += loss
        loss_count += 1
        
        # 정기적으로 학습 결과 출력
        if (iters+1) % 10 == 0:
            avg_loss = total_loss / loss_count
            print('| 에폭 {} | 반복 {} / {} | 손실 {:.2f}'.format(epoch + 1, iters + 1, max_iters, avg_loss))
            loss_list_append(avg_loss)
            total_loss, loss_count = 0, 0
# Out:
# | 에폭 1 | 반복 10 / 10 | 손실 1.12
# | 에폭 2 | 반복 10 / 10 | 손실 1.12
# | 에폭 3 | 반복 10 / 10 | 손실 1.11
# | 에폭 4 | 반복 10 / 10 | 손실 1.14
# | 에폭 5 | 반복 10 / 10 | 손실 1.16
# | 에폭 6 | 반복 10 / 10 | 손실 1.11
# | 에폭 7 | 반복 10 / 10 | 손실 1.12
# | 에폭 8 | 반복 10 / 10 | 손실 1.13
# | 에폭 9 | 반복 10 / 10 | 손실 1.12
# | 에폭 10 | 반복 10 / 10 | 손실 1.11
# | 에폭 11 | 반복 10 / 10 | 손실 1.09
# | 에폭 12 | 반복 10 / 10 | 손실 1.08
# | 에폭 13 | 반복 10 / 10 | 손실 1.04
# | 에폭 14 | 반복 10 / 10 | 손실 1.03
# | 에폭 15 | 반복 10 / 10 | 손실 0.96
# | 에폭 16 | 반복 10 / 10 | 손실 0.92
# | 에폭 17 | 반복 10 / 10 | 손실 0.92
# | 에폭 18 | 반복 10 / 10 | 손실 0.87
# | 에폭 19 | 반복 10 / 10 | 손실 0.85
# | 에폭 20 | 반복 10 / 10 | 손실 0.82
# | 에폭 21 | 반복 10 / 10 | 손실 0.79
# | 에폭 22 | 반복 10 / 10 | 손실 0.78
# | 에폭 23 | 반복 10 / 10 | 손실 0.82
# | 에폭 24 | 반복 10 / 10 | 손실 0.78
# | 에폭 25 | 반복 10 / 10 | 손실 0.76
# | 에폭 26 | 반복 10 / 10 | 손실 0.76
# | 에폭 27 | 반복 10 / 10 | 손실 0.78
# | 에폭 28 | 반복 10 / 10 | 손실 0.75
# | 에폭 29 | 반복 10 / 10 | 손실 0.78
# | 에폭 30 | 반복 10 / 10 | 손실 0.77
# | 에폭 31 | 반복 10 / 10 | 손실 0.77
# | 에폭 32 | 반복 10 / 10 | 손실 0.78
# | 에폭 33 | 반복 10 / 10 | 손실 0.75
# | 에폭 34 | 반복 10 / 10 | 손실 0.74
# | 에폭 35 | 반복 10 / 10 | 손실 0.76
# | 에폭 36 | 반복 10 / 10 | 손실 0.76
# | 에폭 37 | 반복 10 / 10 | 손실 0.73
# | 에폭 38 | 반복 10 / 10 | 손실 0.75
# | 에폭 39 | 반복 10 / 10 | 손실 0.76
# | 에폭 40 | 반복 10 / 10 | 손실 0.76
# | 에폭 41 | 반복 10 / 10 | 손실 0.76
# | 에폭 42 | 반복 10 / 10 | 손실 0.74
# | 에폭 43 | 반복 10 / 10 | 손실 0.75
# | 에폭 44 | 반복 10 / 10 | 손실 0.73
# | 에폭 45 | 반복 10 / 10 | 손실 0.72
# | 에폭 46 | 반복 10 / 10 | 손실 0.73
# | 에폭 47 | 반복 10 / 10 | 손실 0.72
# | 에폭 48 | 반복 10 / 10 | 손실 0.72
# | 에폭 49 | 반복 10 / 10 | 손실 0.72
# | 에폭 50 | 반복 10 / 10 | 손실 0.72
# | 에폭 51 | 반복 10 / 10 | 손실 0.74
# | 에폭 52 | 반복 10 / 10 | 손실 0.74
# | 에폭 53 | 반복 10 / 10 | 손실 0.72
# | 에폭 54 | 반복 10 / 10 | 손실 0.72
# | 에폭 55 | 반복 10 / 10 | 손실 0.71
# | 에폭 56 | 반복 10 / 10 | 손실 0.70
# | 에폭 57 | 반복 10 / 10 | 손실 0.72
# | 에폭 58 | 반복 10 / 10 | 손실 0.70
# | 에폭 59 | 반복 10 / 10 | 손실 0.71
# | 에폭 60 | 반복 10 / 10 | 손실 0.72
# | 에폭 61 | 반복 10 / 10 | 손실 0.70
# | 에폭 62 | 반복 10 / 10 | 손실 0.71
# | 에폭 63 | 반복 10 / 10 | 손실 0.73
# | 에폭 64 | 반복 10 / 10 | 손실 0.70
# | 에폭 65 | 반복 10 / 10 | 손실 0.71
# | 에폭 66 | 반복 10 / 10 | 손실 0.69
# | 에폭 67 | 반복 10 / 10 | 손실 0.70
# | 에폭 68 | 반복 10 / 10 | 손실 0.71
# | 에폭 69 | 반복 10 / 10 | 손실 0.68
# | 에폭 70 | 반복 10 / 10 | 손실 0.69
# | 에폭 71 | 반복 10 / 10 | 손실 0.67
# | 에폭 72 | 반복 10 / 10 | 손실 0.68
# | 에폭 73 | 반복 10 / 10 | 손실 0.67
# | 에폭 74 | 반복 10 / 10 | 손실 0.66
# | 에폭 75 | 반복 10 / 10 | 손실 0.69
# | 에폭 76 | 반복 10 / 10 | 손실 0.64
# | 에폭 77 | 반복 10 / 10 | 손실 0.68
# | 에폭 78 | 반복 10 / 10 | 손실 0.64
# | 에폭 79 | 반복 10 / 10 | 손실 0.64
# | 에폭 80 | 반복 10 / 10 | 손실 0.66
# | 에폭 81 | 반복 10 / 10 | 손실 0.62
# | 에폭 82 | 반복 10 / 10 | 손실 0.62
# | 에폭 83 | 반복 10 / 10 | 손실 0.61
# | 에폭 84 | 반복 10 / 10 | 손실 0.60
# | 에폭 85 | 반복 10 / 10 | 손실 0.60
# | 에폭 86 | 반복 10 / 10 | 손실 0.61
# | 에폭 87 | 반복 10 / 10 | 손실 0.59
# | 에폭 88 | 반복 10 / 10 | 손실 0.58
# | 에폭 89 | 반복 10 / 10 | 손실 0.56
# | 에폭 90 | 반복 10 / 10 | 손실 0.56
# | 에폭 91 | 반복 10 / 10 | 손실 0.54
# | 에폭 92 | 반복 10 / 10 | 손실 0.53
# | 에폭 93 | 반복 10 / 10 | 손실 0.53
# | 에폭 94 | 반복 10 / 10 | 손실 0.52
# | 에폭 95 | 반복 10 / 10 | 손실 0.51
# | 에폭 96 | 반복 10 / 10 | 손실 0.50
# | 에폭 97 | 반복 10 / 10 | 손실 0.48
# | 에폭 98 | 반복 10 / 10 | 손실 0.48
# | 에폭 99 | 반복 10 / 10 | 손실 0.46
# | 에폭 100 | 반복 10 / 10 | 손실 0.45
# | 에폭 101 | 반복 10 / 10 | 손실 0.45
# | 에폭 102 | 반복 10 / 10 | 손실 0.44
# | 에폭 103 | 반복 10 / 10 | 손실 0.44
# | 에폭 104 | 반복 10 / 10 | 손실 0.41
# | 에폭 105 | 반복 10 / 10 | 손실 0.40
# | 에폭 106 | 반복 10 / 10 | 손실 0.41
# | 에폭 107 | 반복 10 / 10 | 손실 0.40
# | 에폭 108 | 반복 10 / 10 | 손실 0.40
# | 에폭 109 | 반복 10 / 10 | 손실 0.38
# | 에폭 110 | 반복 10 / 10 | 손실 0.38
# | 에폭 111 | 반복 10 / 10 | 손실 0.36
# | 에폭 112 | 반복 10 / 10 | 손실 0.37
# | 에폭 113 | 반복 10 / 10 | 손실 0.35
# | 에폭 114 | 반복 10 / 10 | 손실 0.34
# | 에폭 115 | 반복 10 / 10 | 손실 0.34
# | 에폭 116 | 반복 10 / 10 | 손실 0.34
# | 에폭 117 | 반복 10 / 10 | 손실 0.33
# | 에폭 118 | 반복 10 / 10 | 손실 0.34
# | 에폭 119 | 반복 10 / 10 | 손실 0.32
# | 에폭 120 | 반복 10 / 10 | 손실 0.32
# | 에폭 121 | 반복 10 / 10 | 손실 0.31
# | 에폭 122 | 반복 10 / 10 | 손실 0.31
# | 에폭 123 | 반복 10 / 10 | 손실 0.30
# | 에폭 124 | 반복 10 / 10 | 손실 0.30
# | 에폭 125 | 반복 10 / 10 | 손실 0.28
# | 에폭 126 | 반복 10 / 10 | 손실 0.28
# | 에폭 127 | 반복 10 / 10 | 손실 0.28
# | 에폭 128 | 반복 10 / 10 | 손실 0.28
# | 에폭 129 | 반복 10 / 10 | 손실 0.27
# | 에폭 130 | 반복 10 / 10 | 손실 0.27
# | 에폭 131 | 반복 10 / 10 | 손실 0.27
# | 에폭 132 | 반복 10 / 10 | 손실 0.27
# | 에폭 133 | 반복 10 / 10 | 손실 0.27
# | 에폭 134 | 반복 10 / 10 | 손실 0.26
# | 에폭 135 | 반복 10 / 10 | 손실 0.26
# | 에폭 136 | 반복 10 / 10 | 손실 0.26
# | 에폭 137 | 반복 10 / 10 | 손실 0.25
# | 에폭 138 | 반복 10 / 10 | 손실 0.24
# | 에폭 139 | 반복 10 / 10 | 손실 0.24
# | 에폭 140 | 반복 10 / 10 | 손실 0.25
# | 에폭 141 | 반복 10 / 10 | 손실 0.24
# | 에폭 142 | 반복 10 / 10 | 손실 0.24
# | 에폭 143 | 반복 10 / 10 | 손실 0.23
# | 에폭 144 | 반복 10 / 10 | 손실 0.24
# | 에폭 145 | 반복 10 / 10 | 손실 0.23
# | 에폭 146 | 반복 10 / 10 | 손실 0.23
# | 에폭 147 | 반복 10 / 10 | 손실 0.22
# | 에폭 148 | 반복 10 / 10 | 손실 0.22
# | 에폭 149 | 반복 10 / 10 | 손실 0.22
# | 에폭 150 | 반복 10 / 10 | 손실 0.22
# | 에폭 151 | 반복 10 / 10 | 손실 0.22
# | 에폭 152 | 반복 10 / 10 | 손실 0.22
# | 에폭 153 | 반복 10 / 10 | 손실 0.22
# | 에폭 154 | 반복 10 / 10 | 손실 0.21
# | 에폭 155 | 반복 10 / 10 | 손실 0.21
# | 에폭 156 | 반복 10 / 10 | 손실 0.20
# | 에폭 157 | 반복 10 / 10 | 손실 0.21
# | 에폭 158 | 반복 10 / 10 | 손실 0.20
# | 에폭 159 | 반복 10 / 10 | 손실 0.20
# | 에폭 160 | 반복 10 / 10 | 손실 0.20
# | 에폭 161 | 반복 10 / 10 | 손실 0.21
# | 에폭 162 | 반복 10 / 10 | 손실 0.20
# | 에폭 163 | 반복 10 / 10 | 손실 0.20
# | 에폭 164 | 반복 10 / 10 | 손실 0.19
# | 에폭 165 | 반복 10 / 10 | 손실 0.19
# | 에폭 166 | 반복 10 / 10 | 손실 0.19
# | 에폭 167 | 반복 10 / 10 | 손실 0.19
# | 에폭 168 | 반복 10 / 10 | 손실 0.19
# | 에폭 169 | 반복 10 / 10 | 손실 0.19
# | 에폭 170 | 반복 10 / 10 | 손실 0.18
# | 에폭 171 | 반복 10 / 10 | 손실 0.18
# | 에폭 172 | 반복 10 / 10 | 손실 0.18
# | 에폭 173 | 반복 10 / 10 | 손실 0.18
# | 에폭 174 | 반복 10 / 10 | 손실 0.18
# | 에폭 175 | 반복 10 / 10 | 손실 0.18
# | 에폭 176 | 반복 10 / 10 | 손실 0.18
# | 에폭 177 | 반복 10 / 10 | 손실 0.17
# | 에폭 178 | 반복 10 / 10 | 손실 0.17
# | 에폭 179 | 반복 10 / 10 | 손실 0.18
# | 에폭 180 | 반복 10 / 10 | 손실 0.17
# | 에폭 181 | 반복 10 / 10 | 손실 0.18
# | 에폭 182 | 반복 10 / 10 | 손실 0.17
# | 에폭 183 | 반복 10 / 10 | 손실 0.17
# | 에폭 184 | 반복 10 / 10 | 손실 0.18
# | 에폭 185 | 반복 10 / 10 | 손실 0.17
# | 에폭 186 | 반복 10 / 10 | 손실 0.17
# | 에폭 187 | 반복 10 / 10 | 손실 0.17
# | 에폭 188 | 반복 10 / 10 | 손실 0.17
# | 에폭 189 | 반복 10 / 10 | 손실 0.16
# | 에폭 190 | 반복 10 / 10 | 손실 0.17
# | 에폭 191 | 반복 10 / 10 | 손실 0.16
# | 에폭 192 | 반복 10 / 10 | 손실 0.16
# | 에폭 193 | 반복 10 / 10 | 손실 0.16
# | 에폭 194 | 반복 10 / 10 | 손실 0.16
# | 에폭 195 | 반복 10 / 10 | 손실 0.16
# | 에폭 196 | 반복 10 / 10 | 손실 0.15
# | 에폭 197 | 반복 10 / 10 | 손실 0.16
# | 에폭 198 | 반복 10 / 10 | 손실 0.16
# | 에폭 199 | 반복 10 / 10 | 손실 0.15
# | 에폭 200 | 반복 10 / 10 | 손실 0.16
# | 에폭 201 | 반복 10 / 10 | 손실 0.16
# | 에폭 202 | 반복 10 / 10 | 손실 0.15
# | 에폭 203 | 반복 10 / 10 | 손실 0.16
# | 에폭 204 | 반복 10 / 10 | 손실 0.15
# | 에폭 205 | 반복 10 / 10 | 손실 0.15
# | 에폭 206 | 반복 10 / 10 | 손실 0.15
# | 에폭 207 | 반복 10 / 10 | 손실 0.15
# | 에폭 208 | 반복 10 / 10 | 손실 0.15
# | 에폭 209 | 반복 10 / 10 | 손실 0.15
# | 에폭 210 | 반복 10 / 10 | 손실 0.15
# | 에폭 211 | 반복 10 / 10 | 손실 0.15
# | 에폭 212 | 반복 10 / 10 | 손실 0.15
# | 에폭 213 | 반복 10 / 10 | 손실 0.15
# | 에폭 214 | 반복 10 / 10 | 손실 0.14
# | 에폭 215 | 반복 10 / 10 | 손실 0.14
# | 에폭 216 | 반복 10 / 10 | 손실 0.15
# | 에폭 217 | 반복 10 / 10 | 손실 0.14
# | 에폭 218 | 반복 10 / 10 | 손실 0.14
# | 에폭 219 | 반복 10 / 10 | 손실 0.14
# | 에폭 220 | 반복 10 / 10 | 손실 0.14
# | 에폭 221 | 반복 10 / 10 | 손실 0.14
# | 에폭 222 | 반복 10 / 10 | 손실 0.14
# | 에폭 223 | 반복 10 / 10 | 손실 0.14
# | 에폭 224 | 반복 10 / 10 | 손실 0.14
# | 에폭 225 | 반복 10 / 10 | 손실 0.14
# | 에폭 226 | 반복 10 / 10 | 손실 0.14
# | 에폭 227 | 반복 10 / 10 | 손실 0.13
# | 에폭 228 | 반복 10 / 10 | 손실 0.14
# | 에폭 229 | 반복 10 / 10 | 손실 0.13
# | 에폭 230 | 반복 10 / 10 | 손실 0.14
# | 에폭 231 | 반복 10 / 10 | 손실 0.13
# | 에폭 232 | 반복 10 / 10 | 손실 0.13
# | 에폭 233 | 반복 10 / 10 | 손실 0.13
# | 에폭 234 | 반복 10 / 10 | 손실 0.13
# | 에폭 235 | 반복 10 / 10 | 손실 0.14
# | 에폭 236 | 반복 10 / 10 | 손실 0.13
# | 에폭 237 | 반복 10 / 10 | 손실 0.13
# | 에폭 238 | 반복 10 / 10 | 손실 0.14
# | 에폭 239 | 반복 10 / 10 | 손실 0.13
# | 에폭 240 | 반복 10 / 10 | 손실 0.13
# | 에폭 241 | 반복 10 / 10 | 손실 0.13
# | 에폭 242 | 반복 10 / 10 | 손실 0.13
# | 에폭 243 | 반복 10 / 10 | 손실 0.13
# | 에폭 244 | 반복 10 / 10 | 손실 0.13
# | 에폭 245 | 반복 10 / 10 | 손실 0.13
# | 에폭 246 | 반복 10 / 10 | 손실 0.13
# | 에폭 247 | 반복 10 / 10 | 손실 0.13
# | 에폭 248 | 반복 10 / 10 | 손실 0.13
# | 에폭 249 | 반복 10 / 10 | 손실 0.13
# | 에폭 250 | 반복 10 / 10 | 손실 0.12
# | 에폭 251 | 반복 10 / 10 | 손실 0.12
# | 에폭 252 | 반복 10 / 10 | 손실 0.12
# | 에폭 253 | 반복 10 / 10 | 손실 0.12
# | 에폭 254 | 반복 10 / 10 | 손실 0.12
# | 에폭 255 | 반복 10 / 10 | 손실 0.12
# | 에폭 256 | 반복 10 / 10 | 손실 0.12
# | 에폭 257 | 반복 10 / 10 | 손실 0.13
# | 에폭 258 | 반복 10 / 10 | 손실 0.12
# | 에폭 259 | 반복 10 / 10 | 손실 0.13
# | 에폭 260 | 반복 10 / 10 | 손실 0.12
# | 에폭 261 | 반복 10 / 10 | 손실 0.12
# | 에폭 262 | 반복 10 / 10 | 손실 0.13
# | 에폭 263 | 반복 10 / 10 | 손실 0.12
# | 에폭 264 | 반복 10 / 10 | 손실 0.12
# | 에폭 265 | 반복 10 / 10 | 손실 0.12
# | 에폭 266 | 반복 10 / 10 | 손실 0.12
# | 에폭 267 | 반복 10 / 10 | 손실 0.11
# | 에폭 268 | 반복 10 / 10 | 손실 0.12
# | 에폭 269 | 반복 10 / 10 | 손실 0.12
# | 에폭 270 | 반복 10 / 10 | 손실 0.12
# | 에폭 271 | 반복 10 / 10 | 손실 0.12
# | 에폭 272 | 반복 10 / 10 | 손실 0.12
# | 에폭 273 | 반복 10 / 10 | 손실 0.11
# | 에폭 274 | 반복 10 / 10 | 손실 0.12
# | 에폭 275 | 반복 10 / 10 | 손실 0.12
# | 에폭 276 | 반복 10 / 10 | 손실 0.11
# | 에폭 277 | 반복 10 / 10 | 손실 0.11
# | 에폭 278 | 반복 10 / 10 | 손실 0.11
# | 에폭 279 | 반복 10 / 10 | 손실 0.11
# | 에폭 280 | 반복 10 / 10 | 손실 0.12
# | 에폭 281 | 반복 10 / 10 | 손실 0.11
# | 에폭 282 | 반복 10 / 10 | 손실 0.11
# | 에폭 283 | 반복 10 / 10 | 손실 0.11
# | 에폭 284 | 반복 10 / 10 | 손실 0.11
# | 에폭 285 | 반복 10 / 10 | 손실 0.11
# | 에폭 286 | 반복 10 / 10 | 손실 0.12
# | 에폭 287 | 반복 10 / 10 | 손실 0.11
# | 에폭 288 | 반복 10 / 10 | 손실 0.11
# | 에폭 289 | 반복 10 / 10 | 손실 0.11
# | 에폭 290 | 반복 10 / 10 | 손실 0.11
# | 에폭 291 | 반복 10 / 10 | 손실 0.11
# | 에폭 292 | 반복 10 / 10 | 손실 0.11
# | 에폭 293 | 반복 10 / 10 | 손실 0.12
# | 에폭 294 | 반복 10 / 10 | 손실 0.11
# | 에폭 295 | 반복 10 / 10 | 손실 0.12
# | 에폭 296 | 반복 10 / 10 | 손실 0.11
# | 에폭 297 | 반복 10 / 10 | 손실 0.11
# | 에폭 298 | 반복 10 / 10 | 손실 0.11
# | 에폭 299 | 반복 10 / 10 | 손실 0.11
# | 에폭 300 | 반복 10 / 10 | 손실 0.11

# %% [markdown]
# # 그래프 그리기

# %%
# 학습 결과 플롯
plt.plot(np.arange(len(loss_list)), loss_list, label='train')
plt.xlabel('iter (x10)')
plt.ylabel('loss')
plt.show()

# 경계 영역 플롯
h = 0.001
x_min, x_max = x[:, 0].min() - .1, x[:, 0].max() + .1
y_min, y_max = x[:, 1].min() - .1, x[:, 1].max() + .1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
X = np.c_[xx.ravel(), yy.ravel()]
score = model.predict(X)
predict_cls = np.argmax(score, axis=1)
Z = predict_cls.reshape(xx.shape)
plt.contourf(xx, yy, Z)
plt.axis('off')

# 데이터점 플롯
x, t = spiral.load_data()
N = 100
CLS_NUM = 3
markers = ['o', 'x', '^']
for i in range(CLS_NUM):
    plt.scatter(x[i*N:(i+1)*N, 0], x[i*N:(i+1)*N, 1], s=40, marker=markers[i])
plt.show()
