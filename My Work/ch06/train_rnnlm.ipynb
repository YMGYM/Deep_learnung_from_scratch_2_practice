# %%
import import_ipynb
import sys
sys.path.append('..')
from common.optimizer import SGD, Adam
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from ch06.rnnlm import Rnnlm
# Out:
# importing Jupyter notebook from ../common/optimizer.ipynb
# importing Jupyter notebook from ../common/trainer.ipynb
# importing Jupyter notebook from ../common/util.ipynb
# importing Jupyter notebook from ../dataset/ptb.ipynb
# importing Jupyter notebook from ../ch06/rnnlm.ipynb
# importing Jupyter notebook from ../common/time_layers.ipynb
# importing Jupyter notebook from ../common/layers.ipynb
# importing Jupyter notebook from ../common/functions.ipynb
# importing Jupyter notebook from ../common/base_model.ipynb

# %%
batch_size = 20
wordvec_size = 100
hidden_size = 100
time_size = 35

lr = 20.0
max_epoch = 4
max_grad = 0.25

# %%
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# %%
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = RnnlmTrainer(model, optimizer)

# %%
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim = (0, 500))
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 3[s] | 퍼플렉서티 9998.77
# | 에폭 1 |  반복 21 / 1327 | 시간 31[s] | 퍼플렉서티 9699.32
# | 에폭 1 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 4649.57
# | 에폭 1 |  반복 61 / 1327 | 시간 79[s] | 퍼플렉서티 966.83
# | 에폭 1 |  반복 81 / 1327 | 시간 110[s] | 퍼플렉서티 721.57
# | 에폭 1 |  반복 101 / 1327 | 시간 130[s] | 퍼플렉서티 702.08
# | 에폭 1 |  반복 121 / 1327 | 시간 146[s] | 퍼플렉서티 747.54
# | 에폭 1 |  반복 141 / 1327 | 시간 166[s] | 퍼플렉서티 750.60
# | 에폭 1 |  반복 161 / 1327 | 시간 180[s] | 퍼플렉서티 762.37
# | 에폭 1 |  반복 181 / 1327 | 시간 198[s] | 퍼플렉서티 786.15
# | 에폭 1 |  반복 201 / 1327 | 시간 236[s] | 퍼플렉서티 714.24
# | 에폭 1 |  반복 221 / 1327 | 시간 286[s] | 퍼플렉서티 739.69
# | 에폭 1 |  반복 241 / 1327 | 시간 312[s] | 퍼플렉서티 708.66
# | 에폭 1 |  반복 261 / 1327 | 시간 337[s] | 퍼플렉서티 734.36
# | 에폭 1 |  반복 281 / 1327 | 시간 358[s] | 퍼플렉서티 722.25
# | 에폭 1 |  반복 301 / 1327 | 시간 380[s] | 퍼플렉서티 686.77
# | 에폭 1 |  반복 321 / 1327 | 시간 406[s] | 퍼플렉서티 626.14
# | 에폭 1 |  반복 341 / 1327 | 시간 437[s] | 퍼플렉서티 709.99
# | 에폭 1 |  반복 361 / 1327 | 시간 466[s] | 퍼플렉서티 755.51
# | 에폭 1 |  반복 381 / 1327 | 시간 489[s] | 퍼플렉서티 712.11
# | 에폭 1 |  반복 401 / 1327 | 시간 510[s] | 퍼플렉서티 736.55
# | 에폭 1 |  반복 421 / 1327 | 시간 530[s] | 퍼플렉서티 736.98
# | 에폭 1 |  반복 441 / 1327 | 시간 549[s] | 퍼플렉서티 728.30
# | 에폭 1 |  반복 461 / 1327 | 시간 574[s] | 퍼플렉서티 726.16
# | 에폭 1 |  반복 481 / 1327 | 시간 604[s] | 퍼플렉서티 704.23
# | 에폭 1 |  반복 501 / 1327 | 시간 625[s] | 퍼플렉서티 711.90
# | 에폭 1 |  반복 521 / 1327 | 시간 646[s] | 퍼플렉서티 739.16
# | 에폭 1 |  반복 541 / 1327 | 시간 670[s] | 퍼플렉서티 784.88
# | 에폭 1 |  반복 561 / 1327 | 시간 692[s] | 퍼플렉서티 730.24
# | 에폭 1 |  반복 581 / 1327 | 시간 713[s] | 퍼플렉서티 672.69
# | 에폭 1 |  반복 601 / 1327 | 시간 731[s] | 퍼플렉서티 789.88
# | 에폭 1 |  반복 621 / 1327 | 시간 752[s] | 퍼플렉서티 753.49
# | 에폭 1 |  반복 641 / 1327 | 시간 773[s] | 퍼플렉서티 687.43
# | 에폭 1 |  반복 661 / 1327 | 시간 790[s] | 퍼플렉서티 700.90
# | 에폭 1 |  반복 681 / 1327 | 시간 804[s] | 퍼플렉서티 630.38
# | 에폭 1 |  반복 701 / 1327 | 시간 817[s] | 퍼플렉서티 680.66
# | 에폭 1 |  반복 721 / 1327 | 시간 830[s] | 퍼플렉서티 694.23
# | 에폭 1 |  반복 741 / 1327 | 시간 844[s] | 퍼플렉서티 606.44
# | 에폭 1 |  반복 761 / 1327 | 시간 857[s] | 퍼플렉서티 609.97
# | 에폭 1 |  반복 781 / 1327 | 시간 869[s] | 퍼플렉서티 622.13
# | 에폭 1 |  반복 801 / 1327 | 시간 883[s] | 퍼플렉서티 651.40
# | 에폭 1 |  반복 821 / 1327 | 시간 906[s] | 퍼플렉서티 625.99
# | 에폭 1 |  반복 841 / 1327 | 시간 922[s] | 퍼플렉서티 649.04
# | 에폭 1 |  반복 861 / 1327 | 시간 949[s] | 퍼플렉서티 648.71
# | 에폭 1 |  반복 881 / 1327 | 시간 975[s] | 퍼플렉서티 602.77
# | 에폭 1 |  반복 901 / 1327 | 시간 993[s] | 퍼플렉서티 647.25
# | 에폭 1 |  반복 921 / 1327 | 시간 1012[s] | 퍼플렉서티 633.38
# | 에폭 1 |  반복 941 / 1327 | 시간 1026[s] | 퍼플렉서티 605.35
# | 에폭 1 |  반복 961 / 1327 | 시간 1042[s] | 퍼플렉서티 651.81
# | 에폭 1 |  반복 981 / 1327 | 시간 1056[s] | 퍼플렉서티 630.17
# | 에폭 1 |  반복 1001 / 1327 | 시간 1071[s] | 퍼플렉서티 580.22
# | 에폭 1 |  반복 1021 / 1327 | 시간 1090[s] | 퍼플렉서티 619.09
# | 에폭 1 |  반복 1041 / 1327 | 시간 1102[s] | 퍼플렉서티 601.82
# | 에폭 1 |  반복 1061 / 1327 | 시간 1114[s] | 퍼플렉서티 602.84
# | 에폭 1 |  반복 1081 / 1327 | 시간 1126[s] | 퍼플렉서티 545.61
# | 에폭 1 |  반복 1101 / 1327 | 시간 1136[s] | 퍼플렉서티 561.67
# | 에폭 1 |  반복 1121 / 1327 | 시간 1146[s] | 퍼플렉서티 645.73
# | 에폭 1 |  반복 1141 / 1327 | 시간 1157[s] | 퍼플렉서티 609.20
# | 에폭 1 |  반복 1161 / 1327 | 시간 1168[s] | 퍼플렉서티 574.40
# | 에폭 1 |  반복 1181 / 1327 | 시간 1180[s] | 퍼플렉서티 569.63
# | 에폭 1 |  반복 1201 / 1327 | 시간 1189[s] | 퍼플렉서티 499.48
# | 에폭 1 |  반복 1221 / 1327 | 시간 1197[s] | 퍼플렉서티 499.57
# | 에폭 1 |  반복 1241 / 1327 | 시간 1206[s] | 퍼플렉서티 569.31
# | 에폭 1 |  반복 1261 / 1327 | 시간 1214[s] | 퍼플렉서티 512.91
# | 에폭 1 |  반복 1281 / 1327 | 시간 1222[s] | 퍼플렉서티 532.94
# | 에폭 1 |  반복 1301 / 1327 | 시간 1231[s] | 퍼플렉서티 627.48
# | 에폭 1 |  반복 1321 / 1327 | 시간 1240[s] | 퍼플렉서티 574.92
# | 에폭 2 |  반복 1 / 1327 | 시간 1243[s] | 퍼플렉서티 594.57
# | 에폭 2 |  반복 21 / 1327 | 시간 1251[s] | 퍼플렉서티 577.38
# | 에폭 2 |  반복 41 / 1327 | 시간 1260[s] | 퍼플렉서티 553.36
# | 에폭 2 |  반복 61 / 1327 | 시간 1269[s] | 퍼플렉서티 521.86
# | 에폭 2 |  반복 81 / 1327 | 시간 1279[s] | 퍼플렉서티 495.62
# | 에폭 2 |  반복 101 / 1327 | 시간 1295[s] | 퍼플렉서티 466.54
# | 에폭 2 |  반복 121 / 1327 | 시간 1316[s] | 퍼플렉서티 501.94
# | 에폭 2 |  반복 141 / 1327 | 시간 1329[s] | 퍼플렉서티 525.98
# | 에폭 2 |  반복 161 / 1327 | 시간 1342[s] | 퍼플렉서티 539.87
# | 에폭 2 |  반복 181 / 1327 | 시간 1354[s] | 퍼플렉서티 566.11
# | 에폭 2 |  반복 201 / 1327 | 시간 1367[s] | 퍼플렉서티 537.41
# | 에폭 2 |  반복 221 / 1327 | 시간 1380[s] | 퍼플렉서티 548.66
# | 에폭 2 |  반복 241 / 1327 | 시간 1392[s] | 퍼플렉서티 519.46
# | 에폭 2 |  반복 261 / 1327 | 시간 1402[s] | 퍼플렉서티 560.14
# | 에폭 2 |  반복 281 / 1327 | 시간 1410[s] | 퍼플렉서티 553.68
# | 에폭 2 |  반복 301 / 1327 | 시간 1419[s] | 퍼플렉서티 497.84
# | 에폭 2 |  반복 321 / 1327 | 시간 1427[s] | 퍼플렉서티 448.71
# | 에폭 2 |  반복 341 / 1327 | 시간 1436[s] | 퍼플렉서티 511.06
# | 에폭 2 |  반복 361 / 1327 | 시간 1450[s] | 퍼플렉서티 570.53
# | 에폭 2 |  반복 381 / 1327 | 시간 1459[s] | 퍼플렉서티 513.76
# | 에폭 2 |  반복 401 / 1327 | 시간 1467[s] | 퍼플렉서티 515.21
# | 에폭 2 |  반복 421 / 1327 | 시간 1477[s] | 퍼플렉서티 519.30
# | 에폭 2 |  반복 441 / 1327 | 시간 1490[s] | 퍼플렉서티 510.65
# | 에폭 2 |  반복 461 / 1327 | 시간 1501[s] | 퍼플렉서티 501.13
# | 에폭 2 |  반복 481 / 1327 | 시간 1512[s] | 퍼플렉서티 497.33
# | 에폭 2 |  반복 501 / 1327 | 시간 1522[s] | 퍼플렉서티 505.91
# | 에폭 2 |  반복 521 / 1327 | 시간 1538[s] | 퍼플렉서티 508.66
# | 에폭 2 |  반복 541 / 1327 | 시간 1553[s] | 퍼플렉서티 527.71
# | 에폭 2 |  반복 561 / 1327 | 시간 1567[s] | 퍼플렉서티 504.86
# | 에폭 2 |  반복 581 / 1327 | 시간 1578[s] | 퍼플렉서티 468.78
# | 에폭 2 |  반복 601 / 1327 | 시간 1588[s] | 퍼플렉서티 585.72
# | 에폭 2 |  반복 621 / 1327 | 시간 1598[s] | 퍼플렉서티 550.35
# | 에폭 2 |  반복 641 / 1327 | 시간 1610[s] | 퍼플렉서티 508.77
# | 에폭 2 |  반복 661 / 1327 | 시간 1624[s] | 퍼플렉서티 496.15
# | 에폭 2 |  반복 681 / 1327 | 시간 1637[s] | 퍼플렉서티 437.42
# | 에폭 2 |  반복 701 / 1327 | 시간 1647[s] | 퍼플렉서티 485.64
# | 에폭 2 |  반복 721 / 1327 | 시간 1657[s] | 퍼플렉서티 505.07
# | 에폭 2 |  반복 741 / 1327 | 시간 1667[s] | 퍼플렉서티 434.77
# | 에폭 2 |  반복 761 / 1327 | 시간 1676[s] | 퍼플렉서티 441.74
# | 에폭 2 |  반복 781 / 1327 | 시간 1690[s] | 퍼플렉서티 454.73
# | 에폭 2 |  반복 801 / 1327 | 시간 1704[s] | 퍼플렉서티 471.51
# | 에폭 2 |  반복 821 / 1327 | 시간 1724[s] | 퍼플렉서티 459.23
# | 에폭 2 |  반복 841 / 1327 | 시간 1741[s] | 퍼플렉서티 468.76
# | 에폭 2 |  반복 861 / 1327 | 시간 1763[s] | 퍼플렉서티 482.57
# | 에폭 2 |  반복 881 / 1327 | 시간 1777[s] | 퍼플렉서티 451.76
# | 에폭 2 |  반복 901 / 1327 | 시간 1791[s] | 퍼플렉서티 483.24
# | 에폭 2 |  반복 921 / 1327 | 시간 1800[s] | 퍼플렉서티 471.67
# | 에폭 2 |  반복 941 / 1327 | 시간 1809[s] | 퍼플렉서티 472.28
# | 에폭 2 |  반복 961 / 1327 | 시간 1820[s] | 퍼플렉서티 498.87
# | 에폭 2 |  반복 981 / 1327 | 시간 1834[s] | 퍼플렉서티 477.71
# | 에폭 2 |  반복 1001 / 1327 | 시간 1845[s] | 퍼플렉서티 437.58
# | 에폭 2 |  반복 1021 / 1327 | 시간 1853[s] | 퍼플렉서티 480.38
# | 에폭 2 |  반복 1041 / 1327 | 시간 1862[s] | 퍼플렉서티 462.05
# | 에폭 2 |  반복 1061 / 1327 | 시간 1872[s] | 퍼플렉서티 458.67
# | 에폭 2 |  반복 1081 / 1327 | 시간 1880[s] | 퍼플렉서티 418.58
# | 에폭 2 |  반복 1101 / 1327 | 시간 1890[s] | 퍼플렉서티 435.59
# | 에폭 2 |  반복 1121 / 1327 | 시간 1899[s] | 퍼플렉서티 499.15
# | 에폭 2 |  반복 1141 / 1327 | 시간 1908[s] | 퍼플렉서티 472.53
# | 에폭 2 |  반복 1161 / 1327 | 시간 1917[s] | 퍼플렉서티 451.08
# | 에폭 2 |  반복 1181 / 1327 | 시간 1925[s] | 퍼플렉서티 445.59
# | 에폭 2 |  반복 1201 / 1327 | 시간 1934[s] | 퍼플렉서티 389.27
# | 에폭 2 |  반복 1221 / 1327 | 시간 1944[s] | 퍼플렉서티 394.08
# | 에폭 2 |  반복 1241 / 1327 | 시간 1954[s] | 퍼플렉서티 452.44
# | 에폭 2 |  반복 1261 / 1327 | 시간 1963[s] | 퍼플렉서티 413.32
# | 에폭 2 |  반복 1281 / 1327 | 시간 1973[s] | 퍼플렉서티 422.07
# | 에폭 2 |  반복 1301 / 1327 | 시간 1989[s] | 퍼플렉서티 514.09
# | 에폭 2 |  반복 1321 / 1327 | 시간 2002[s] | 퍼플렉서티 469.40
# | 에폭 3 |  반복 1 / 1327 | 시간 2006[s] | 퍼플렉서티 482.10
# | 에폭 3 |  반복 21 / 1327 | 시간 2015[s] | 퍼플렉서티 468.28
# | 에폭 3 |  반복 41 / 1327 | 시간 2024[s] | 퍼플렉서티 456.27
# | 에폭 3 |  반복 61 / 1327 | 시간 2032[s] | 퍼플렉서티 422.43
# | 에폭 3 |  반복 81 / 1327 | 시간 2040[s] | 퍼플렉서티 409.99
# | 에폭 3 |  반복 101 / 1327 | 시간 2049[s] | 퍼플렉서티 376.38
# | 에폭 3 |  반복 121 / 1327 | 시간 2061[s] | 퍼플렉서티 420.18
# | 에폭 3 |  반복 141 / 1327 | 시간 2072[s] | 퍼플렉서티 433.38
# | 에폭 3 |  반복 161 / 1327 | 시간 2081[s] | 퍼플렉서티 452.42
# | 에폭 3 |  반복 181 / 1327 | 시간 2089[s] | 퍼플렉서티 477.40
# | 에폭 3 |  반복 201 / 1327 | 시간 2097[s] | 퍼플렉서티 445.95
# | 에폭 3 |  반복 221 / 1327 | 시간 2105[s] | 퍼플렉서티 456.90
# | 에폭 3 |  반복 241 / 1327 | 시간 2114[s] | 퍼플렉서티 436.85
# | 에폭 3 |  반복 261 / 1327 | 시간 2122[s] | 퍼플렉서티 454.88
# | 에폭 3 |  반복 281 / 1327 | 시간 2130[s] | 퍼플렉서티 467.90
# | 에폭 3 |  반복 301 / 1327 | 시간 2139[s] | 퍼플렉서티 414.17
# | 에폭 3 |  반복 321 / 1327 | 시간 2149[s] | 퍼플렉서티 378.21
# | 에폭 3 |  반복 341 / 1327 | 시간 2157[s] | 퍼플렉서티 413.20
# | 에폭 3 |  반복 361 / 1327 | 시간 2166[s] | 퍼플렉서티 489.67
# | 에폭 3 |  반복 381 / 1327 | 시간 2180[s] | 퍼플렉서티 425.24
# | 에폭 3 |  반복 401 / 1327 | 시간 2189[s] | 퍼플렉서티 436.67
# | 에폭 3 |  반복 421 / 1327 | 시간 2200[s] | 퍼플렉서티 434.05
# | 에폭 3 |  반복 441 / 1327 | 시간 2208[s] | 퍼플렉서티 430.10
# | 에폭 3 |  반복 461 / 1327 | 시간 2216[s] | 퍼플렉서티 427.73
# | 에폭 3 |  반복 481 / 1327 | 시간 2225[s] | 퍼플렉서티 422.29
# | 에폭 3 |  반복 501 / 1327 | 시간 2233[s] | 퍼플렉서티 422.29
# | 에폭 3 |  반복 521 / 1327 | 시간 2242[s] | 퍼플렉서티 430.12
# | 에폭 3 |  반복 541 / 1327 | 시간 2250[s] | 퍼플렉서티 445.59
