# %%
import import_ipynb
import sys
sys.path.append('..')
from common.optimizer import SGD, Adam
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from ch06.rnnlm import Rnnlm
# Out:
# importing Jupyter notebook from ../common/optimizer.ipynb
# importing Jupyter notebook from ../common/trainer.ipynb
# importing Jupyter notebook from ../common/util.ipynb
# importing Jupyter notebook from ../dataset/ptb.ipynb
# importing Jupyter notebook from ../ch06/rnnlm.ipynb
# importing Jupyter notebook from ../common/time_layers.ipynb
# importing Jupyter notebook from ../common/layers.ipynb
# importing Jupyter notebook from ../common/functions.ipynb
# importing Jupyter notebook from ../common/base_model.ipynb

# %%
batch_size = 20
wordvec_size = 100
hidden_size = 100
time_size = 35

lr = 0.02
max_epoch = 4
max_grad = 0.25

# %%
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# %%
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# %%
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim = (0, 500))
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 10000.43
# | 에폭 1 |  반복 21 / 1327 | 시간 8[s] | 퍼플렉서티 9967.34
# | 에폭 1 |  반복 41 / 1327 | 시간 16[s] | 퍼플렉서티 9905.85
# | 에폭 1 |  반복 61 / 1327 | 시간 23[s] | 퍼플렉서티 9842.37
# | 에폭 1 |  반복 81 / 1327 | 시간 31[s] | 퍼플렉서티 9787.47
# | 에폭 1 |  반복 101 / 1327 | 시간 39[s] | 퍼플렉서티 9722.25
# | 에폭 1 |  반복 121 / 1327 | 시간 47[s] | 퍼플렉서티 9661.84
# | 에폭 1 |  반복 141 / 1327 | 시간 55[s] | 퍼플렉서티 9602.78
# | 에폭 1 |  반복 161 / 1327 | 시간 63[s] | 퍼플렉서티 9528.73
# | 에폭 1 |  반복 181 / 1327 | 시간 71[s] | 퍼플렉서티 9483.62
# | 에폭 1 |  반복 201 / 1327 | 시간 79[s] | 퍼플렉서티 9396.38
# | 에폭 1 |  반복 221 / 1327 | 시간 90[s] | 퍼플렉서티 9350.48
# | 에폭 1 |  반복 241 / 1327 | 시간 98[s] | 퍼플렉서티 9292.08
# | 에폭 1 |  반복 261 / 1327 | 시간 106[s] | 퍼플렉서티 9263.17
# | 에폭 1 |  반복 281 / 1327 | 시간 114[s] | 퍼플렉서티 9181.36
# | 에폭 1 |  반복 301 / 1327 | 시간 122[s] | 퍼플렉서티 9123.89
# | 에폭 1 |  반복 321 / 1327 | 시간 130[s] | 퍼플렉서티 9020.07
# | 에폭 1 |  반복 341 / 1327 | 시간 139[s] | 퍼플렉서티 8976.55
# | 에폭 1 |  반복 361 / 1327 | 시간 148[s] | 퍼플렉서티 8940.27
# | 에폭 1 |  반복 381 / 1327 | 시간 156[s] | 퍼플렉서티 8885.34
# | 에폭 1 |  반복 401 / 1327 | 시간 165[s] | 퍼플렉서티 8787.14
# | 에폭 1 |  반복 421 / 1327 | 시간 173[s] | 퍼플렉서티 8757.66
# | 에폭 1 |  반복 441 / 1327 | 시간 181[s] | 퍼플렉서티 8655.10
# | 에폭 1 |  반복 461 / 1327 | 시간 190[s] | 퍼플렉서티 8655.41
# | 에폭 1 |  반복 481 / 1327 | 시간 199[s] | 퍼플렉서티 8550.37
# | 에폭 1 |  반복 501 / 1327 | 시간 210[s] | 퍼플렉서티 8434.40
# | 에폭 1 |  반복 521 / 1327 | 시간 219[s] | 퍼플렉서티 8399.70
# | 에폭 1 |  반복 541 / 1327 | 시간 229[s] | 퍼플렉서티 8379.43
# | 에폭 1 |  반복 561 / 1327 | 시간 239[s] | 퍼플렉서티 8278.62
# | 에폭 1 |  반복 581 / 1327 | 시간 248[s] | 퍼플렉서티 8210.96
# | 에폭 1 |  반복 601 / 1327 | 시간 257[s] | 퍼플렉서티 8205.69
# | 에폭 1 |  반복 621 / 1327 | 시간 267[s] | 퍼플렉서티 8070.07
# | 에폭 1 |  반복 641 / 1327 | 시간 276[s] | 퍼플렉서티 7911.87
# | 에폭 1 |  반복 661 / 1327 | 시간 285[s] | 퍼플렉서티 7894.43
# | 에폭 1 |  반복 681 / 1327 | 시간 294[s] | 퍼플렉서티 7810.78
# | 에폭 1 |  반복 701 / 1327 | 시간 303[s] | 퍼플렉서티 7750.43
# | 에폭 1 |  반복 721 / 1327 | 시간 313[s] | 퍼플렉서티 7686.46
# | 에폭 1 |  반복 741 / 1327 | 시간 321[s] | 퍼플렉서티 7517.63
# | 에폭 1 |  반복 761 / 1327 | 시간 330[s] | 퍼플렉서티 7427.87
# | 에폭 1 |  반복 781 / 1327 | 시간 339[s] | 퍼플렉서티 7319.07
# | 에폭 1 |  반복 801 / 1327 | 시간 349[s] | 퍼플렉서티 7293.55
# | 에폭 1 |  반복 821 / 1327 | 시간 358[s] | 퍼플렉서티 7206.23
# | 에폭 1 |  반복 841 / 1327 | 시간 368[s] | 퍼플렉서티 7136.64
# | 에폭 1 |  반복 861 / 1327 | 시간 376[s] | 퍼플렉서티 7057.62
# | 에폭 1 |  반복 881 / 1327 | 시간 385[s] | 퍼플렉서티 6998.99
# | 에폭 1 |  반복 901 / 1327 | 시간 394[s] | 퍼플렉서티 6732.85
# | 에폭 1 |  반복 921 / 1327 | 시간 403[s] | 퍼플렉서티 6715.51
# | 에폭 1 |  반복 941 / 1327 | 시간 412[s] | 퍼플렉서티 6583.85
# | 에폭 1 |  반복 961 / 1327 | 시간 425[s] | 퍼플렉서티 6600.89
# | 에폭 1 |  반복 981 / 1327 | 시간 434[s] | 퍼플렉서티 6510.58
# | 에폭 1 |  반복 1001 / 1327 | 시간 443[s] | 퍼플렉서티 6371.44
# | 에폭 1 |  반복 1021 / 1327 | 시간 451[s] | 퍼플렉서티 6220.88
# | 에폭 1 |  반복 1041 / 1327 | 시간 462[s] | 퍼플렉서티 5988.48
# | 에폭 1 |  반복 1061 / 1327 | 시간 471[s] | 퍼플렉서티 6087.73
# | 에폭 1 |  반복 1081 / 1327 | 시간 481[s] | 퍼플렉서티 5916.80
# | 에폭 1 |  반복 1101 / 1327 | 시간 490[s] | 퍼플렉서티 5719.11
# | 에폭 1 |  반복 1121 / 1327 | 시간 498[s] | 퍼플렉서티 5756.95
# | 에폭 1 |  반복 1141 / 1327 | 시간 508[s] | 퍼플렉서티 5718.14
# | 에폭 1 |  반복 1161 / 1327 | 시간 519[s] | 퍼플렉서티 5411.82
# | 에폭 1 |  반복 1181 / 1327 | 시간 528[s] | 퍼플렉서티 5427.94
# | 에폭 1 |  반복 1201 / 1327 | 시간 539[s] | 퍼플렉서티 5275.00
# | 에폭 1 |  반복 1221 / 1327 | 시간 550[s] | 퍼플렉서티 5212.52
# | 에폭 1 |  반복 1241 / 1327 | 시간 559[s] | 퍼플렉서티 5096.65
# | 에폭 1 |  반복 1261 / 1327 | 시간 569[s] | 퍼플렉서티 4880.92
# | 에폭 1 |  반복 1281 / 1327 | 시간 579[s] | 퍼플렉서티 4898.21
# | 에폭 1 |  반복 1301 / 1327 | 시간 589[s] | 퍼플렉서티 4863.75
# | 에폭 1 |  반복 1321 / 1327 | 시간 598[s] | 퍼플렉서티 4676.15
# | 에폭 2 |  반복 1 / 1327 | 시간 602[s] | 퍼플렉서티 4672.48
# | 에폭 2 |  반복 21 / 1327 | 시간 611[s] | 퍼플렉서티 4638.58
# | 에폭 2 |  반복 41 / 1327 | 시간 620[s] | 퍼플렉서티 4532.54
# | 에폭 2 |  반복 61 / 1327 | 시간 629[s] | 퍼플렉서티 4457.75
# | 에폭 2 |  반복 81 / 1327 | 시간 638[s] | 퍼플렉서티 4453.99
# | 에폭 2 |  반복 101 / 1327 | 시간 646[s] | 퍼플렉서티 4332.75
# | 에폭 2 |  반복 121 / 1327 | 시간 654[s] | 퍼플렉서티 4222.65
# | 에폭 2 |  반복 141 / 1327 | 시간 663[s] | 퍼플렉서티 4163.57
# | 에폭 2 |  반복 161 / 1327 | 시간 672[s] | 퍼플렉서티 3974.39
# | 에폭 2 |  반복 181 / 1327 | 시간 681[s] | 퍼플렉서티 3974.90
# | 에폭 2 |  반복 201 / 1327 | 시간 691[s] | 퍼플렉서티 3798.13
# | 에폭 2 |  반복 221 / 1327 | 시간 701[s] | 퍼플렉서티 3789.14
# | 에폭 2 |  반복 241 / 1327 | 시간 709[s] | 퍼플렉서티 3744.86
# | 에폭 2 |  반복 261 / 1327 | 시간 719[s] | 퍼플렉서티 3839.69
# | 에폭 2 |  반복 281 / 1327 | 시간 729[s] | 퍼플렉서티 3674.75
# | 에폭 2 |  반복 301 / 1327 | 시간 737[s] | 퍼플렉서티 3585.24
# | 에폭 2 |  반복 321 / 1327 | 시간 746[s] | 퍼플렉서티 3347.27
# | 에폭 2 |  반복 341 / 1327 | 시간 755[s] | 퍼플렉서티 3351.83
# | 에폭 2 |  반복 361 / 1327 | 시간 764[s] | 퍼플렉서티 3391.07
# | 에폭 2 |  반복 381 / 1327 | 시간 772[s] | 퍼플렉서티 3404.96
# | 에폭 2 |  반복 401 / 1327 | 시간 781[s] | 퍼플렉서티 3188.49
# | 에폭 2 |  반복 421 / 1327 | 시간 789[s] | 퍼플렉서티 3224.43
# | 에폭 2 |  반복 441 / 1327 | 시간 798[s] | 퍼플렉서티 3076.74
# | 에폭 2 |  반복 461 / 1327 | 시간 807[s] | 퍼플렉서티 3199.60
# | 에폭 2 |  반복 481 / 1327 | 시간 816[s] | 퍼플렉서티 3025.46
# | 에폭 2 |  반복 501 / 1327 | 시간 825[s] | 퍼플렉서티 2853.94
# | 에폭 2 |  반복 521 / 1327 | 시간 834[s] | 퍼플렉서티 2889.77
# | 에폭 2 |  반복 541 / 1327 | 시간 843[s] | 퍼플렉서티 2953.75
# | 에폭 2 |  반복 561 / 1327 | 시간 851[s] | 퍼플렉서티 2861.20
# | 에폭 2 |  반복 581 / 1327 | 시간 860[s] | 퍼플렉서티 2774.13
# | 에폭 2 |  반복 601 / 1327 | 시간 869[s] | 퍼플렉서티 2915.80
# | 에폭 2 |  반복 621 / 1327 | 시간 877[s] | 퍼플렉서티 2728.58
# | 에폭 2 |  반복 641 / 1327 | 시간 885[s] | 퍼플렉서티 2537.28
# | 에폭 2 |  반복 661 / 1327 | 시간 893[s] | 퍼플렉서티 2531.92
# | 에폭 2 |  반복 681 / 1327 | 시간 900[s] | 퍼플렉서티 2528.64
# | 에폭 2 |  반복 701 / 1327 | 시간 908[s] | 퍼플렉서티 2548.08
# | 에폭 2 |  반복 721 / 1327 | 시간 916[s] | 퍼플렉서티 2551.26
# | 에폭 2 |  반복 741 / 1327 | 시간 924[s] | 퍼플렉서티 2335.50
# | 에폭 2 |  반복 761 / 1327 | 시간 931[s] | 퍼플렉서티 2270.05
# | 에폭 2 |  반복 781 / 1327 | 시간 940[s] | 퍼플렉서티 2225.01
# | 에폭 2 |  반복 801 / 1327 | 시간 948[s] | 퍼플렉서티 2271.86
# | 에폭 2 |  반복 821 / 1327 | 시간 957[s] | 퍼플렉서티 2287.24
# | 에폭 2 |  반복 841 / 1327 | 시간 966[s] | 퍼플렉서티 2295.84
# | 에폭 2 |  반복 861 / 1327 | 시간 974[s] | 퍼플렉서티 2295.51
# | 에폭 2 |  반복 881 / 1327 | 시간 983[s] | 퍼플렉서티 2296.42
# | 에폭 2 |  반복 901 / 1327 | 시간 991[s] | 퍼플렉서티 2058.55
# | 에폭 2 |  반복 921 / 1327 | 시간 1000[s] | 퍼플렉서티 2130.21
# | 에폭 2 |  반복 941 / 1327 | 시간 1008[s] | 퍼플렉서티 2059.15
# | 에폭 2 |  반복 961 / 1327 | 시간 1017[s] | 퍼플렉서티 2238.63
# | 에폭 2 |  반복 981 / 1327 | 시간 1026[s] | 퍼플렉서티 2165.24
# | 에폭 2 |  반복 1001 / 1327 | 시간 1035[s] | 퍼플렉서티 2131.33
# | 에폭 2 |  반복 1021 / 1327 | 시간 1043[s] | 퍼플렉서티 2033.07
# | 에폭 2 |  반복 1041 / 1327 | 시간 1052[s] | 퍼플렉서티 1867.03
# | 에폭 2 |  반복 1061 / 1327 | 시간 1060[s] | 퍼플렉서티 2098.80
# | 에폭 2 |  반복 1081 / 1327 | 시간 1068[s] | 퍼플렉서티 1941.69
# | 에폭 2 |  반복 1101 / 1327 | 시간 1076[s] | 퍼플렉서티 1823.77
# | 에폭 2 |  반복 1121 / 1327 | 시간 1084[s] | 퍼플렉서티 2021.68
# | 에폭 2 |  반복 1141 / 1327 | 시간 1093[s] | 퍼플렉서티 2043.57
# | 에폭 2 |  반복 1161 / 1327 | 시간 1102[s] | 퍼플렉서티 1850.77
# | 에폭 2 |  반복 1181 / 1327 | 시간 1110[s] | 퍼플렉서티 1916.03
# | 에폭 2 |  반복 1201 / 1327 | 시간 1119[s] | 퍼플렉서티 1786.04
# | 에폭 2 |  반복 1221 / 1327 | 시간 1128[s] | 퍼플렉서티 1775.03
# | 에폭 2 |  반복 1241 / 1327 | 시간 1136[s] | 퍼플렉서티 1860.99
# | 에폭 2 |  반복 1261 / 1327 | 시간 1146[s] | 퍼플렉서티 1673.97
# | 에폭 2 |  반복 1281 / 1327 | 시간 1155[s] | 퍼플렉서티 1726.18
# | 에폭 2 |  반복 1301 / 1327 | 시간 1163[s] | 퍼플렉서티 1823.88
# | 에폭 2 |  반복 1321 / 1327 | 시간 1172[s] | 퍼플렉서티 1730.68
# | 에폭 3 |  반복 1 / 1327 | 시간 1175[s] | 퍼플렉서티 1757.95
# | 에폭 3 |  반복 21 / 1327 | 시간 1184[s] | 퍼플렉서티 1771.04
# | 에폭 3 |  반복 41 / 1327 | 시간 1192[s] | 퍼플렉서티 1748.65
# | 에폭 3 |  반복 61 / 1327 | 시간 1201[s] | 퍼플렉서티 1743.69
# | 에폭 3 |  반복 81 / 1327 | 시간 1209[s] | 퍼플렉서티 1768.47
# | 에폭 3 |  반복 101 / 1327 | 시간 1219[s] | 퍼플렉서티 1707.21
# | 에폭 3 |  반복 121 / 1327 | 시간 1227[s] | 퍼플렉서티 1703.34
# | 에폭 3 |  반복 141 / 1327 | 시간 1235[s] | 퍼플렉서티 1710.96
# | 에폭 3 |  반복 161 / 1327 | 시간 1244[s] | 퍼플렉서티 1641.50
# | 에폭 3 |  반복 181 / 1327 | 시간 1253[s] | 퍼플렉서티 1716.14
# | 에폭 3 |  반복 201 / 1327 | 시간 1263[s] | 퍼플렉서티 1614.63
# | 에폭 3 |  반복 221 / 1327 | 시간 1277[s] | 퍼플렉서티 1647.63
# | 에폭 3 |  반복 241 / 1327 | 시간 1288[s] | 퍼플렉서티 1640.42
# | 에폭 3 |  반복 261 / 1327 | 시간 1298[s] | 퍼플렉서티 1768.35
# | 에폭 3 |  반복 281 / 1327 | 시간 1308[s] | 퍼플렉서티 1703.15
# | 에폭 3 |  반복 301 / 1327 | 시간 1318[s] | 퍼플렉서티 1628.20
# | 에폭 3 |  반복 321 / 1327 | 시간 1328[s] | 퍼플렉서티 1479.84
# | 에폭 3 |  반복 341 / 1327 | 시간 1338[s] | 퍼플렉서티 1518.01
# | 에폭 3 |  반복 361 / 1327 | 시간 1347[s] | 퍼플렉서티 1671.58
# | 에폭 3 |  반복 381 / 1327 | 시간 1356[s] | 퍼플렉서티 1686.15
# | 에폭 3 |  반복 401 / 1327 | 시간 1366[s] | 퍼플렉서티 1570.35
# | 에폭 3 |  반복 421 / 1327 | 시간 1376[s] | 퍼플렉서티 1618.73
# | 에폭 3 |  반복 441 / 1327 | 시간 1388[s] | 퍼플렉서티 1536.01
# | 에폭 3 |  반복 461 / 1327 | 시간 1398[s] | 퍼플렉서티 1636.67
# | 에폭 3 |  반복 481 / 1327 | 시간 1408[s] | 퍼플렉서티 1568.85
# | 에폭 3 |  반복 501 / 1327 | 시간 1418[s] | 퍼플렉서티 1459.32
# | 에폭 3 |  반복 521 / 1327 | 시간 1428[s] | 퍼플렉서티 1544.05
# | 에폭 3 |  반복 541 / 1327 | 시간 1438[s] | 퍼플렉서티 1635.54
# | 에폭 3 |  반복 561 / 1327 | 시간 1449[s] | 퍼플렉서티 1581.46
# | 에폭 3 |  반복 581 / 1327 | 시간 1458[s] | 퍼플렉서티 1477.62
# | 에폭 3 |  반복 601 / 1327 | 시간 1468[s] | 퍼플렉서티 1675.29
# | 에폭 3 |  반복 621 / 1327 | 시간 1478[s] | 퍼플렉서티 1593.04
# | 에폭 3 |  반복 641 / 1327 | 시간 1488[s] | 퍼플렉서티 1463.57
# | 에폭 3 |  반복 661 / 1327 | 시간 1496[s] | 퍼플렉서티 1454.59
# | 에폭 3 |  반복 681 / 1327 | 시간 1505[s] | 퍼플렉서티 1439.94
# | 에폭 3 |  반복 701 / 1327 | 시간 1515[s] | 퍼플렉서티 1511.89
# | 에폭 3 |  반복 721 / 1327 | 시간 1524[s] | 퍼플렉서티 1513.25
# | 에폭 3 |  반복 741 / 1327 | 시간 1535[s] | 퍼플렉서티 1380.72
# | 에폭 3 |  반복 761 / 1327 | 시간 1545[s] | 퍼플렉서티 1370.78
# | 에폭 3 |  반복 781 / 1327 | 시간 1554[s] | 퍼플렉서티 1324.79
# | 에폭 3 |  반복 801 / 1327 | 시간 1563[s] | 퍼플렉서티 1374.58
# | 에폭 3 |  반복 821 / 1327 | 시간 1573[s] | 퍼플렉서티 1421.12
# | 에폭 3 |  반복 841 / 1327 | 시간 1584[s] | 퍼플렉서티 1424.27
# | 에폭 3 |  반복 861 / 1327 | 시간 1595[s] | 퍼플렉서티 1464.73
# | 에폭 3 |  반복 881 / 1327 | 시간 1605[s] | 퍼플렉서티 1452.78
# | 에폭 3 |  반복 901 / 1327 | 시간 1613[s] | 퍼플렉서티 1326.38
# | 에폭 3 |  반복 921 / 1327 | 시간 1624[s] | 퍼플렉서티 1390.89
# | 에폭 3 |  반복 941 / 1327 | 시간 1634[s] | 퍼플렉서티 1370.60
# | 에폭 3 |  반복 961 / 1327 | 시간 1645[s] | 퍼플렉서티 1476.38
# | 에폭 3 |  반복 981 / 1327 | 시간 1654[s] | 퍼플렉서티 1429.89
# | 에폭 3 |  반복 1001 / 1327 | 시간 1664[s] | 퍼플렉서티 1387.75
# | 에폭 3 |  반복 1021 / 1327 | 시간 1675[s] | 퍼플렉서티 1379.69
# | 에폭 3 |  반복 1041 / 1327 | 시간 1685[s] | 퍼플렉서티 1267.18
# | 에폭 3 |  반복 1061 / 1327 | 시간 1695[s] | 퍼플렉서티 1418.36
# | 에폭 3 |  반복 1081 / 1327 | 시간 1705[s] | 퍼플렉서티 1328.13
# | 에폭 3 |  반복 1101 / 1327 | 시간 1714[s] | 퍼플렉서티 1273.83
# | 에폭 3 |  반복 1121 / 1327 | 시간 1724[s] | 퍼플렉서티 1404.73
# | 에폭 3 |  반복 1141 / 1327 | 시간 1734[s] | 퍼플렉서티 1437.11
# | 에폭 3 |  반복 1161 / 1327 | 시간 1743[s] | 퍼플렉서티 1323.67
# | 에폭 3 |  반복 1181 / 1327 | 시간 1753[s] | 퍼플렉서티 1342.50
# | 에폭 3 |  반복 1201 / 1327 | 시간 1762[s] | 퍼플렉서티 1257.99
# | 에폭 3 |  반복 1221 / 1327 | 시간 1772[s] | 퍼플렉서티 1223.85
# | 에폭 3 |  반복 1241 / 1327 | 시간 1781[s] | 퍼플렉서티 1328.08
# | 에폭 3 |  반복 1261 / 1327 | 시간 1790[s] | 퍼플렉서티 1206.05
# | 에폭 3 |  반복 1281 / 1327 | 시간 1800[s] | 퍼플렉서티 1255.63
# | 에폭 3 |  반복 1301 / 1327 | 시간 1810[s] | 퍼플렉서티 1358.33
# | 에폭 3 |  반복 1321 / 1327 | 시간 1820[s] | 퍼플렉서티 1275.98
# | 에폭 4 |  반복 1 / 1327 | 시간 1824[s] | 퍼플렉서티 1270.05
# | 에폭 4 |  반복 21 / 1327 | 시간 1833[s] | 퍼플렉서티 1327.65
# | 에폭 4 |  반복 41 / 1327 | 시간 1842[s] | 퍼플렉서티 1292.57
# | 에폭 4 |  반복 61 / 1327 | 시간 1851[s] | 퍼플렉서티 1298.34
# | 에폭 4 |  반복 81 / 1327 | 시간 1860[s] | 퍼플렉서티 1273.32
# | 에폭 4 |  반복 101 / 1327 | 시간 1869[s] | 퍼플렉서티 1226.02
# | 에폭 4 |  반복 121 / 1327 | 시간 1879[s] | 퍼플렉서티 1284.60
# | 에폭 4 |  반복 141 / 1327 | 시간 1889[s] | 퍼플렉서티 1281.87
# | 에폭 4 |  반복 161 / 1327 | 시간 1898[s] | 퍼플렉서티 1228.35
# | 에폭 4 |  반복 181 / 1327 | 시간 1906[s] | 퍼플렉서티 1287.08
# | 에폭 4 |  반복 201 / 1327 | 시간 1916[s] | 퍼플렉서티 1220.75
# | 에폭 4 |  반복 221 / 1327 | 시간 1926[s] | 퍼플렉서티 1257.94
# | 에폭 4 |  반복 241 / 1327 | 시간 1935[s] | 퍼플렉서티 1247.64
# | 에폭 4 |  반복 261 / 1327 | 시간 1944[s] | 퍼플렉서티 1332.05
# | 에폭 4 |  반복 281 / 1327 | 시간 1954[s] | 퍼플렉서티 1301.76
# | 에폭 4 |  반복 301 / 1327 | 시간 1963[s] | 퍼플렉서티 1234.16
# | 에폭 4 |  반복 321 / 1327 | 시간 1972[s] | 퍼플렉서티 1149.49
# | 에폭 4 |  반복 341 / 1327 | 시간 1981[s] | 퍼플렉서티 1154.77
# | 에폭 4 |  반복 361 / 1327 | 시간 1990[s] | 퍼플렉서티 1312.33
# | 에폭 4 |  반복 381 / 1327 | 시간 1999[s] | 퍼플렉서티 1286.45
# | 에폭 4 |  반복 401 / 1327 | 시간 2008[s] | 퍼플렉서티 1210.10
# | 에폭 4 |  반복 421 / 1327 | 시간 2017[s] | 퍼플렉서티 1270.93
# | 에폭 4 |  반복 441 / 1327 | 시간 2027[s] | 퍼플렉서티 1182.88
# | 에폭 4 |  반복 461 / 1327 | 시간 2037[s] | 퍼플렉서티 1256.15
# | 에폭 4 |  반복 481 / 1327 | 시간 2049[s] | 퍼플렉서티 1237.68
# | 에폭 4 |  반복 501 / 1327 | 시간 2058[s] | 퍼플렉서티 1135.16
# | 에폭 4 |  반복 521 / 1327 | 시간 2068[s] | 퍼플렉서티 1184.59
# | 에폭 4 |  반복 541 / 1327 | 시간 2076[s] | 퍼플렉서티 1270.80
# | 에폭 4 |  반복 561 / 1327 | 시간 2084[s] | 퍼플렉서티 1249.09
# | 에폭 4 |  반복 581 / 1327 | 시간 2091[s] | 퍼플렉서티 1140.06
# | 에폭 4 |  반복 601 / 1327 | 시간 2099[s] | 퍼플렉서티 1326.10
# | 에폭 4 |  반복 621 / 1327 | 시간 2107[s] | 퍼플렉서티 1284.27
# | 에폭 4 |  반복 641 / 1327 | 시간 2115[s] | 퍼플렉서티 1183.04
# | 에폭 4 |  반복 661 / 1327 | 시간 2123[s] | 퍼플렉서티 1149.17
# | 에폭 4 |  반복 681 / 1327 | 시간 2130[s] | 퍼플렉서티 1118.90
# | 에폭 4 |  반복 701 / 1327 | 시간 2138[s] | 퍼플렉서티 1195.55
# | 에폭 4 |  반복 721 / 1327 | 시간 2145[s] | 퍼플렉서티 1195.35
# | 에폭 4 |  반복 741 / 1327 | 시간 2153[s] | 퍼플렉서티 1093.92
# | 에폭 4 |  반복 761 / 1327 | 시간 2161[s] | 퍼플렉서티 1104.85
# | 에폭 4 |  반복 781 / 1327 | 시간 2170[s] | 퍼플렉서티 1048.73
# | 에폭 4 |  반복 801 / 1327 | 시간 2179[s] | 퍼플렉서티 1103.81
# | 에폭 4 |  반복 821 / 1327 | 시간 2190[s] | 퍼플렉서티 1119.20
# | 에폭 4 |  반복 841 / 1327 | 시간 2199[s] | 퍼플렉서티 1131.30
# | 에폭 4 |  반복 861 / 1327 | 시간 2206[s] | 퍼플렉서티 1186.65
# | 에폭 4 |  반복 881 / 1327 | 시간 2215[s] | 퍼플렉서티 1148.35
# | 에폭 4 |  반복 901 / 1327 | 시간 2223[s] | 퍼플렉서티 1091.36
# | 에폭 4 |  반복 921 / 1327 | 시간 2231[s] | 퍼플렉서티 1138.93
# | 에폭 4 |  반복 941 / 1327 | 시간 2239[s] | 퍼플렉서티 1111.34
# | 에폭 4 |  반복 961 / 1327 | 시간 2247[s] | 퍼플렉서티 1202.46
# | 에폭 4 |  반복 981 / 1327 | 시간 2255[s] | 퍼플렉서티 1146.38
# | 에폭 4 |  반복 1001 / 1327 | 시간 2263[s] | 퍼플렉서티 1113.86
# | 에폭 4 |  반복 1021 / 1327 | 시간 2270[s] | 퍼플렉서티 1135.97
# | 에폭 4 |  반복 1041 / 1327 | 시간 2278[s] | 퍼플렉서티 1047.16
# | 에폭 4 |  반복 1061 / 1327 | 시간 2286[s] | 퍼플렉서티 1150.12
# | 에폭 4 |  반복 1081 / 1327 | 시간 2294[s] | 퍼플렉서티 1096.01
# | 에폭 4 |  반복 1101 / 1327 | 시간 2301[s] | 퍼플렉서티 1054.47
# | 에폭 4 |  반복 1121 / 1327 | 시간 2309[s] | 퍼플렉서티 1156.33
# | 에폭 4 |  반복 1141 / 1327 | 시간 2317[s] | 퍼플렉서티 1184.45
# | 에폭 4 |  반복 1161 / 1327 | 시간 2324[s] | 퍼플렉서티 1107.05
# | 에폭 4 |  반복 1181 / 1327 | 시간 2332[s] | 퍼플렉서티 1098.79
# | 에폭 4 |  반복 1201 / 1327 | 시간 2339[s] | 퍼플렉서티 1040.54
# | 에폭 4 |  반복 1221 / 1327 | 시간 2347[s] | 퍼플렉서티 996.73
# | 에폭 4 |  반복 1241 / 1327 | 시간 2356[s] | 퍼플렉서티 1094.19
# | 에폭 4 |  반복 1261 / 1327 | 시간 2364[s] | 퍼플렉서티 1012.17
# | 에폭 4 |  반복 1281 / 1327 | 시간 2372[s] | 퍼플렉서티 1044.49
# | 에폭 4 |  반복 1301 / 1327 | 시간 2379[s] | 퍼플렉서티 1165.62
# | 에폭 4 |  반복 1321 / 1327 | 시간 2387[s] | 퍼플렉서티 1074.61
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 끄지 말아주세요
# ### 내리고 사용해도 됩니다
