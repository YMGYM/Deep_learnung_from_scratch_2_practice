# %%
import import_ipynb
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from ch06.rnnlm import Rnnlm
# Out:
# importing Jupyter notebook from ../common/optimizer.ipynb
# importing Jupyter notebook from ../common/trainer.ipynb
# importing Jupyter notebook from ../common/util.ipynb
# importing Jupyter notebook from ../dataset/ptb.ipynb
# importing Jupyter notebook from ../ch06/rnnlm.ipynb
# importing Jupyter notebook from ../common/time_layers.ipynb
# importing Jupyter notebook from ../common/layers.ipynb
# importing Jupyter notebook from ../common/functions.ipynb
# importing Jupyter notebook from ../common/base_model.ipynb

# %%
batch_size = 20
wordvec_size = 100
hidden_size = 100
time_size = 35

lr = 20.0
max_epoch = 4
max_grad = 0.25

# %%
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# %%
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# %%
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim = (0, 500))
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 10001.12
# | 에폭 1 |  반복 21 / 1327 | 시간 10[s] | 퍼플렉서티 2426.62
# | 에폭 1 |  반복 41 / 1327 | 시간 21[s] | 퍼플렉서티 1816.83
# | 에폭 1 |  반복 61 / 1327 | 시간 31[s] | 퍼플렉서티 1164.79
# | 에폭 1 |  반복 81 / 1327 | 시간 41[s] | 퍼플렉서티 925.70
# | 에폭 1 |  반복 101 / 1327 | 시간 51[s] | 퍼플렉서티 779.12
# | 에폭 1 |  반복 121 / 1327 | 시간 60[s] | 퍼플렉서티 780.78
# | 에폭 1 |  반복 141 / 1327 | 시간 71[s] | 퍼플렉서티 713.81
# | 에폭 1 |  반복 161 / 1327 | 시간 82[s] | 퍼플렉서티 696.53
# | 에폭 1 |  반복 181 / 1327 | 시간 91[s] | 퍼플렉서티 676.25
# | 에폭 1 |  반복 201 / 1327 | 시간 102[s] | 퍼플렉서티 620.71
# | 에폭 1 |  반복 221 / 1327 | 시간 111[s] | 퍼플렉서티 624.20
# | 에폭 1 |  반복 241 / 1327 | 시간 121[s] | 퍼플렉서티 568.55
# | 에폭 1 |  반복 261 / 1327 | 시간 131[s] | 퍼플렉서티 617.20
# | 에폭 1 |  반복 281 / 1327 | 시간 141[s] | 퍼플렉서티 587.44
# | 에폭 1 |  반복 301 / 1327 | 시간 151[s] | 퍼플렉서티 529.54
# | 에폭 1 |  반복 321 / 1327 | 시간 161[s] | 퍼플렉서티 478.68
# | 에폭 1 |  반복 341 / 1327 | 시간 172[s] | 퍼플렉서티 552.56
# | 에폭 1 |  반복 361 / 1327 | 시간 188[s] | 퍼플렉서티 591.88
# | 에폭 1 |  반복 381 / 1327 | 시간 206[s] | 퍼플렉서티 517.92
# | 에폭 1 |  반복 401 / 1327 | 시간 218[s] | 퍼플렉서티 538.49
# | 에폭 1 |  반복 421 / 1327 | 시간 233[s] | 퍼플렉서티 534.26
# | 에폭 1 |  반복 441 / 1327 | 시간 244[s] | 퍼플렉서티 507.75
# | 에폭 1 |  반복 461 / 1327 | 시간 254[s] | 퍼플렉서티 515.45
# | 에폭 1 |  반복 481 / 1327 | 시간 263[s] | 퍼플렉서티 503.46
# | 에폭 1 |  반복 501 / 1327 | 시간 273[s] | 퍼플렉서티 517.36
# | 에폭 1 |  반복 521 / 1327 | 시간 282[s] | 퍼플렉서티 499.95
# | 에폭 1 |  반복 541 / 1327 | 시간 293[s] | 퍼플렉서티 523.17
# | 에폭 1 |  반복 561 / 1327 | 시간 305[s] | 퍼플렉서티 481.20
# | 에폭 1 |  반복 581 / 1327 | 시간 315[s] | 퍼플렉서티 453.28
# | 에폭 1 |  반복 601 / 1327 | 시간 326[s] | 퍼플렉서티 581.01
# | 에폭 1 |  반복 621 / 1327 | 시간 338[s] | 퍼플렉서티 529.07
# | 에폭 1 |  반복 641 / 1327 | 시간 348[s] | 퍼플렉서티 483.15
# | 에폭 1 |  반복 661 / 1327 | 시간 357[s] | 퍼플렉서티 476.26
# ../common/functions.ipynb:2: RuntimeWarning: overflow encountered in exp
#   "cells": [
# | 에폭 1 |  반복 681 / 1327 | 시간 367[s] | 퍼플렉서티 435.40
# | 에폭 1 |  반복 701 / 1327 | 시간 377[s] | 퍼플렉서티 455.52
# | 에폭 1 |  반복 721 / 1327 | 시간 386[s] | 퍼플렉서티 459.20
# | 에폭 1 |  반복 741 / 1327 | 시간 396[s] | 퍼플렉서티 400.51
# | 에폭 1 |  반복 761 / 1327 | 시간 407[s] | 퍼플렉서티 438.48
# | 에폭 1 |  반복 781 / 1327 | 시간 416[s] | 퍼플렉서티 417.62
# | 에폭 1 |  반복 801 / 1327 | 시간 426[s] | 퍼플렉서티 453.23
# | 에폭 1 |  반복 821 / 1327 | 시간 436[s] | 퍼플렉서티 428.25
# | 에폭 1 |  반복 841 / 1327 | 시간 446[s] | 퍼플렉서티 444.78
# | 에폭 1 |  반복 861 / 1327 | 시간 455[s] | 퍼플렉서티 455.90
# | 에폭 1 |  반복 881 / 1327 | 시간 466[s] | 퍼플렉서티 415.08
# | 에폭 1 |  반복 901 / 1327 | 시간 475[s] | 퍼플렉서티 480.67
# | 에폭 1 |  반복 921 / 1327 | 시간 484[s] | 퍼플렉서티 456.85
# | 에폭 1 |  반복 941 / 1327 | 시간 493[s] | 퍼플렉서티 456.26
# | 에폭 1 |  반복 961 / 1327 | 시간 502[s] | 퍼플렉서티 500.33
# | 에폭 1 |  반복 981 / 1327 | 시간 512[s] | 퍼플렉서티 472.63
# | 에폭 1 |  반복 1001 / 1327 | 시간 522[s] | 퍼플렉서티 418.43
# | 에폭 1 |  반복 1021 / 1327 | 시간 531[s] | 퍼플렉서티 478.52
# | 에폭 1 |  반복 1041 / 1327 | 시간 540[s] | 퍼플렉서티 458.95
# | 에폭 1 |  반복 1061 / 1327 | 시간 549[s] | 퍼플렉서티 465.25
# | 에폭 1 |  반복 1081 / 1327 | 시간 559[s] | 퍼플렉서티 420.06
# | 에폭 1 |  반복 1101 / 1327 | 시간 568[s] | 퍼플렉서티 437.97
# | 에폭 1 |  반복 1121 / 1327 | 시간 577[s] | 퍼플렉서티 505.54
# | 에폭 1 |  반복 1141 / 1327 | 시간 587[s] | 퍼플렉서티 489.69
# | 에폭 1 |  반복 1161 / 1327 | 시간 596[s] | 퍼플렉서티 476.38
# | 에폭 1 |  반복 1181 / 1327 | 시간 608[s] | 퍼플렉서티 448.32
# | 에폭 1 |  반복 1201 / 1327 | 시간 618[s] | 퍼플렉서티 383.88
# | 에폭 1 |  반복 1221 / 1327 | 시간 628[s] | 퍼플렉서티 390.08
# | 에폭 1 |  반복 1241 / 1327 | 시간 638[s] | 퍼플렉서티 458.00
# | 에폭 1 |  반복 1261 / 1327 | 시간 648[s] | 퍼플렉서티 404.11
# | 에폭 1 |  반복 1281 / 1327 | 시간 658[s] | 퍼플렉서티 429.03
# | 에폭 1 |  반복 1301 / 1327 | 시간 668[s] | 퍼플렉서티 510.24
# | 에폭 1 |  반복 1321 / 1327 | 시간 679[s] | 퍼플렉서티 491.43
# | 에폭 2 |  반복 1 / 1327 | 시간 683[s] | 퍼플렉서티 480.52
# | 에폭 2 |  반복 21 / 1327 | 시간 694[s] | 퍼플렉서티 488.33
# | 에폭 2 |  반복 41 / 1327 | 시간 705[s] | 퍼플렉서티 463.48
# | 에폭 2 |  반복 61 / 1327 | 시간 716[s] | 퍼플렉서티 428.63
# | 에폭 2 |  반복 81 / 1327 | 시간 727[s] | 퍼플렉서티 405.44
# | 에폭 2 |  반복 101 / 1327 | 시간 741[s] | 퍼플렉서티 394.35
# | 에폭 2 |  반복 121 / 1327 | 시간 753[s] | 퍼플렉서티 420.18
# | 에폭 2 |  반복 141 / 1327 | 시간 764[s] | 퍼플렉서티 454.42
# | 에폭 2 |  반복 161 / 1327 | 시간 776[s] | 퍼플렉서티 453.03
# | 에폭 2 |  반복 181 / 1327 | 시간 788[s] | 퍼플렉서티 487.62
# | 에폭 2 |  반복 201 / 1327 | 시간 801[s] | 퍼플렉서티 456.92
# | 에폭 2 |  반복 221 / 1327 | 시간 813[s] | 퍼플렉서티 460.79
# | 에폭 2 |  반복 241 / 1327 | 시간 826[s] | 퍼플렉서티 450.27
# | 에폭 2 |  반복 261 / 1327 | 시간 840[s] | 퍼플렉서티 457.05
# | 에폭 2 |  반복 281 / 1327 | 시간 858[s] | 퍼플렉서티 470.29
# | 에폭 2 |  반복 301 / 1327 | 시간 871[s] | 퍼플렉서티 424.45
# | 에폭 2 |  반복 321 / 1327 | 시간 884[s] | 퍼플렉서티 380.45
# | 에폭 2 |  반복 341 / 1327 | 시간 900[s] | 퍼플렉서티 451.64
# | 에폭 2 |  반복 361 / 1327 | 시간 914[s] | 퍼플렉서티 513.91
# | 에폭 2 |  반복 381 / 1327 | 시간 932[s] | 퍼플렉서티 444.58
# | 에폭 2 |  반복 401 / 1327 | 시간 946[s] | 퍼플렉서티 455.85
# | 에폭 2 |  반복 421 / 1327 | 시간 960[s] | 퍼플렉서티 454.61
# | 에폭 2 |  반복 441 / 1327 | 시간 974[s] | 퍼플렉서티 454.10
# | 에폭 2 |  반복 461 / 1327 | 시간 988[s] | 퍼플렉서티 440.11
# | 에폭 2 |  반복 481 / 1327 | 시간 1003[s] | 퍼플렉서티 454.93
# | 에폭 2 |  반복 501 / 1327 | 시간 1017[s] | 퍼플렉서티 458.72
# | 에폭 2 |  반복 521 / 1327 | 시간 1032[s] | 퍼플렉서티 448.91
# | 에폭 2 |  반복 541 / 1327 | 시간 1047[s] | 퍼플렉서티 475.61
# | 에폭 2 |  반복 561 / 1327 | 시간 1062[s] | 퍼플렉서티 458.47
# | 에폭 2 |  반복 581 / 1327 | 시간 1076[s] | 퍼플렉서티 416.09
# | 에폭 2 |  반복 601 / 1327 | 시간 1090[s] | 퍼플렉서티 534.05
# | 에폭 2 |  반복 621 / 1327 | 시간 1105[s] | 퍼플렉서티 511.90
# | 에폭 2 |  반복 641 / 1327 | 시간 1119[s] | 퍼플렉서티 465.10
# | 에폭 2 |  반복 661 / 1327 | 시간 1133[s] | 퍼플렉서티 442.90
# | 에폭 2 |  반복 681 / 1327 | 시간 1147[s] | 퍼플렉서티 388.13
# | 에폭 2 |  반복 701 / 1327 | 시간 1161[s] | 퍼플렉서티 433.75
# | 에폭 2 |  반복 721 / 1327 | 시간 1175[s] | 퍼플렉서티 454.18
# | 에폭 2 |  반복 741 / 1327 | 시간 1190[s] | 퍼플렉서티 389.47
# | 에폭 2 |  반복 761 / 1327 | 시간 1204[s] | 퍼플렉서티 409.85
# | 에폭 2 |  반복 781 / 1327 | 시간 1218[s] | 퍼플렉서티 416.32
# | 에폭 2 |  반복 801 / 1327 | 시간 1232[s] | 퍼플렉서티 435.23
# | 에폭 2 |  반복 821 / 1327 | 시간 1250[s] | 퍼플렉서티 431.31
# | 에폭 2 |  반복 841 / 1327 | 시간 1269[s] | 퍼플렉서티 443.52
# | 에폭 2 |  반복 861 / 1327 | 시간 1286[s] | 퍼플렉서티 448.02
# | 에폭 2 |  반복 881 / 1327 | 시간 1302[s] | 퍼플렉서티 406.24
# | 에폭 2 |  반복 901 / 1327 | 시간 1319[s] | 퍼플렉서티 456.35
# | 에폭 2 |  반복 921 / 1327 | 시간 1335[s] | 퍼플렉서티 438.75
# | 에폭 2 |  반복 941 / 1327 | 시간 1352[s] | 퍼플렉서티 447.38
# | 에폭 2 |  반복 961 / 1327 | 시간 1367[s] | 퍼플렉서티 494.68
# | 에폭 2 |  반복 981 / 1327 | 시간 1385[s] | 퍼플렉서티 453.34
# | 에폭 2 |  반복 1001 / 1327 | 시간 1406[s] | 퍼플렉서티 401.61
# | 에폭 2 |  반복 1021 / 1327 | 시간 1424[s] | 퍼플렉서티 460.50
# | 에폭 2 |  반복 1041 / 1327 | 시간 1442[s] | 퍼플렉서티 421.05
# | 에폭 2 |  반복 1061 / 1327 | 시간 1459[s] | 퍼플렉서티 412.72
# | 에폭 2 |  반복 1081 / 1327 | 시간 1474[s] | 퍼플렉서티 395.35
# | 에폭 2 |  반복 1101 / 1327 | 시간 1491[s] | 퍼플렉서티 407.08
# | 에폭 2 |  반복 1121 / 1327 | 시간 1506[s] | 퍼플렉서티 479.29
# | 에폭 2 |  반복 1141 / 1327 | 시간 1523[s] | 퍼플렉서티 435.80
# | 에폭 2 |  반복 1161 / 1327 | 시간 1538[s] | 퍼플렉서티 425.12
# | 에폭 2 |  반복 1181 / 1327 | 시간 1555[s] | 퍼플렉서티 423.41
# | 에폭 2 |  반복 1201 / 1327 | 시간 1571[s] | 퍼플렉서티 365.87
# | 에폭 2 |  반복 1221 / 1327 | 시간 1587[s] | 퍼플렉서티 369.91
# | 에폭 2 |  반복 1241 / 1327 | 시간 1606[s] | 퍼플렉서티 429.53
# | 에폭 2 |  반복 1261 / 1327 | 시간 1623[s] | 퍼플렉서티 393.83
# | 에폭 2 |  반복 1281 / 1327 | 시간 1641[s] | 퍼플렉서티 418.48
# | 에폭 2 |  반복 1301 / 1327 | 시간 1663[s] | 퍼플렉서티 488.39
# | 에폭 2 |  반복 1321 / 1327 | 시간 1680[s] | 퍼플렉서티 449.52
# | 에폭 3 |  반복 1 / 1327 | 시간 1686[s] | 퍼플렉서티 490.47
# | 에폭 3 |  반복 21 / 1327 | 시간 1702[s] | 퍼플렉서티 466.57
# | 에폭 3 |  반복 41 / 1327 | 시간 1719[s] | 퍼플렉서티 468.24
# | 에폭 3 |  반복 61 / 1327 | 시간 1735[s] | 퍼플렉서티 413.90
# | 에폭 3 |  반복 81 / 1327 | 시간 1752[s] | 퍼플렉서티 399.61
# | 에폭 3 |  반복 101 / 1327 | 시간 1768[s] | 퍼플렉서티 375.64
# | 에폭 3 |  반복 121 / 1327 | 시간 1786[s] | 퍼플렉서티 408.79
# | 에폭 3 |  반복 141 / 1327 | 시간 1803[s] | 퍼플렉서티 421.01
# | 에폭 3 |  반복 161 / 1327 | 시간 1819[s] | 퍼플렉서티 439.18
# | 에폭 3 |  반복 181 / 1327 | 시간 1836[s] | 퍼플렉서티 473.80
# | 에폭 3 |  반복 201 / 1327 | 시간 1853[s] | 퍼플렉서티 434.37
# | 에폭 3 |  반복 221 / 1327 | 시간 1870[s] | 퍼플렉서티 444.67
# | 에폭 3 |  반복 241 / 1327 | 시간 1887[s] | 퍼플렉서티 423.36
# | 에폭 3 |  반복 261 / 1327 | 시간 1904[s] | 퍼플렉서티 448.17
# | 에폭 3 |  반복 281 / 1327 | 시간 1923[s] | 퍼플렉서티 470.46
# | 에폭 3 |  반복 301 / 1327 | 시간 1941[s] | 퍼플렉서티 425.81
# | 에폭 3 |  반복 321 / 1327 | 시간 1958[s] | 퍼플렉서티 389.30
# | 에폭 3 |  반복 341 / 1327 | 시간 1977[s] | 퍼플렉서티 424.82
# | 에폭 3 |  반복 361 / 1327 | 시간 1994[s] | 퍼플렉서티 509.47
# | 에폭 3 |  반복 381 / 1327 | 시간 2012[s] | 퍼플렉서티 435.41
# | 에폭 3 |  반복 401 / 1327 | 시간 2030[s] | 퍼플렉서티 445.63
# | 에폭 3 |  반복 421 / 1327 | 시간 2047[s] | 퍼플렉서티 437.87
# | 에폭 3 |  반복 441 / 1327 | 시간 2065[s] | 퍼플렉서티 435.66
# | 에폭 3 |  반복 461 / 1327 | 시간 2082[s] | 퍼플렉서티 445.30
# | 에폭 3 |  반복 481 / 1327 | 시간 2099[s] | 퍼플렉서티 437.98
# | 에폭 3 |  반복 501 / 1327 | 시간 2118[s] | 퍼플렉서티 457.19
# | 에폭 3 |  반복 521 / 1327 | 시간 2137[s] | 퍼플렉서티 451.21
# | 에폭 3 |  반복 541 / 1327 | 시간 2155[s] | 퍼플렉서티 465.72
# | 에폭 3 |  반복 561 / 1327 | 시간 2173[s] | 퍼플렉서티 442.47
